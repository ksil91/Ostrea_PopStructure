# %% [markdown]
# Code from here: https://github.com/wlz0726/Population_Genomics_Scripts/wiki/Treemix

# %% [markdown]
# # x45m75 Neutral

# %%
source("../../../General_Methods/treemix-1.13/src/plotting_funcs_Me.R")

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -o OL-c85t10m45x75n_unrooted > out")

# %% [markdown]
# Plot Treemix, using functions that come with Treemix

# %%
plot_resid("OL-c85t10m45x75n_unrooted","TMorder")
# Out:
# [1] 0.0003561709
# [1] "here"
# Warning message in .Internal(lapply(X, FUN)):
# “closing unused connection 5 (OL-c85t10m45x75n_unrooted.cov.gz)”Warning message in .Internal(lapply(X, FUN)):
# “closing unused connection 4 (OL-c85t10m45x75n_unrooted.cov.gz)”Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “NAs introduced by coercion”
#    Klaskino_BC   Barkeley_BC  Ladysmith_BC Victoria_BC  Discovery_WA
# 1   0.0000003000  0.000000640  0.001145950 -0.001095452  0.000124050
# 2   0.0000006400  0.000000300  0.002461530 -0.000860604  0.000676620
# 3   0.0011459500  0.002461530  0.000000320 -0.000867280  0.001302510
# 4  -0.0010954520 -0.000860604 -0.000867280  0.000000300 -0.001319550
# 5   0.0001240500  0.000676620  0.001302510 -0.001319550  0.000000320
# 6  -0.0006026640 -0.000472195  0.000466400  0.000453650 -0.000626870
# 7  -0.0003687680 -0.000035510 -0.000239220  0.000979780  0.000580240
# 8  -0.0005267580 -0.000438562 -0.000659230 -0.000111320  0.000048540
# ...

# %%
plot <- plot_tree("OL-c85t10m45x75_unrooted","TMorder")
# Out:
# Warning message in plot_tree("OL-c85t10m45x75_unrooted", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-c85t10m45x75_unrooted", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-c85t10m45x75_unrooted", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-c85t10m45x75_unrooted", "TMorder"):
# “NAs introduced by coercion”Warning message in max(e[e[, 5] == "MIG", 4]):
# “no non-missing arguments to max; returning -Inf”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# Plot Treemix, using functions that come with Treemix

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz  -root SanDiego_CA,MuguLagoon_CA -o OL-x45m75-neut-u_socal > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal","TMorder")
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal", "TMorder"):
# “NAs introduced by coercion”Warning message in max(e[e[, 5] == "MIG", 4]):
# “no non-missing arguments to max; returning -Inf”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# ## M1

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 1 -o OL-x45m75-neut-u_socal_m1 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m1","TMorder")
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal_m1", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m1", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m1", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m1", "TMorder"):
# “NAs introduced by coercion”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# ## M2

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 2 -o OL-x45m75-neut-u_socal_m2 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m2","TMorder")
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal_m2", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m2", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m2", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m2", "TMorder"):
# “NAs introduced by coercion”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# ## M3

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 3 -o OL-x45m75-neut-u_socal_m3 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m3","TMorder")
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal_m3", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m3", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m3", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m3", "TMorder"):
# “NAs introduced by coercion”Warning message:
# “closing unused connection 4 (OL-x45m75-neut-u_socal_m3.vertices.gz)”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# ## M4

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 4 -o OL-x45m75-neut-u_socal_m4 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m4","TMorder")
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal_m4", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m4", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m4", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m4", "TMorder"):
# “NAs introduced by coercion”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# ## M5

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 5 -o OL-x45m75-neut-u_socal_m5 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m5","TMorder")
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal_m5", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m5", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m5", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m5", "TMorder"):
# “NAs introduced by coercion”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# ## M6

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 6 -o OL-x45m75-neut-u_socal_m6 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m6","TMorder")
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal_m6", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m6", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m6", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m6", "TMorder"):
# “NAs introduced by coercion”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# ## M7

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 7 -o OL-x45m75-neut-u_socal_m7 > out")

# %%
t = plot_tree("OL-x45m75-neut-u_socal_m7")
d = t$d
text(d$x, d$y, lab = d[,1])
#plot <- plot_tree("OL-m80x55-maf025-neutI2-u_SoCalrooted", flip = c(604,136,2,256))
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal_m7"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m7"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m7"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m7"):
# “NAs introduced by coercion”
# plot without title

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m7","TMorder",flip = c(52,472,412,304,676,356,172,2),scale = F)
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal_m7", "TMorder", flip = c(52, :
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m7", "TMorder", flip = c(52, :
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m7", "TMorder", flip = c(52, :
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m7", "TMorder", flip = c(52, :
# “NAs introduced by coercion”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# ## M8

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 8 -o OL-x45m75-neut-u_socal_m8 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m8","TMorder")

# %% [markdown]
# ## M9

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 9 -o OL-x45m75-neut-u_socal_m9 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m9","TMorder")
# Out:
# Warning message in plot_tree("OL-x45m75-neut-u_socal_m9", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m9", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m9", "TMorder"):
# “NAs introduced by coercion”Warning message in plot_tree("OL-x45m75-neut-u_socal_m9", "TMorder"):
# “NAs introduced by coercion”Warning message in if (!is.na(o)) {:
# “the condition has length > 1 and only the first element will be used”
# plot without title

# %% [markdown]
# ## M10

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 10 -o OL-x45m75-neut-u_socal_m10 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m2","TMorder")

# %% [markdown]
# ## M11

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 11 -o OL-x45m75-neut-u_socal_m11 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m2","TMorder")

# %% [markdown]
# ## M12

# %%
system("treemix -i ../Inputs/OL-c85t10-x45m75-maf025-neutI2-u.pop.TM.gz -root SanDiego_CA,MuguLagoon_CA -m 12 -o OL-x45m75-neut-u_socal_m12 > out")

# %%
plot <- plot_tree("OL-x45m75-neut-u_socal_m2","TMorder")

# %%
t = plot_tree("OL-m80x55-maf025-neutI2-u_SoCalrooted")
d = t$d
text(d$x, d$y, lab = d[,1])
plot <- plot_tree("OL-m80x55-maf025-neutI2-u_SoCalrooted", flip = c(604,136,2,256))

# %% [markdown]
# ## Comparing ms

# %%
print("M1")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m1",intern=T)

print("M2")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m2",intern=T)

print("M3")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m3",intern=T)

print("M4")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m4",intern=T)

print("M5")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m5",intern=T)

print("M6")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m6",intern=T)

print("M7")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m7",intern=T)

print("M8")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m8",intern=T)

print("M9")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m9",intern=T)

print("M10")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m10",intern=T)

print("M11")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m11",intern=T)

print("M12")
system("perl Population_Genomics_Scripts/03.treemix/treemix_fraction.pl OL-x45m75-neut-u_socal_m12",intern=T)
# Out:
# [1] "M1"
# [1] "The TreeMix ML tree explains 97.17% of the variation. 0.971710055583651"
# [1] "M2"
# [1] "The TreeMix ML tree explains 97.97% of the variation. 0.97971898005183"
# [1] "M3"
# [1] "The TreeMix ML tree explains 98.49% of the variation. 0.984881723644755"
# [1] "M4"
# [1] "The TreeMix ML tree explains 98.81% of the variation. 0.988133578544556"
# [1] "M5"
# [1] "The TreeMix ML tree explains 98.98% of the variation. 0.989839236397274"
# [1] "M6"
# [1] "The TreeMix ML tree explains 99.11% of the variation. 0.991114968112155"
# [1] "M7"
# [1] "The TreeMix ML tree explains 99.33% of the variation. 0.993280230355509"
# [1] "M8"
# [1] "The TreeMix ML tree explains 99.41% of the variation. 0.994146485849138"
# [1] "M9"
# [1] "The TreeMix ML tree explains 99.51% of the variation. 0.995102987512876"
# [1] "M10"
# [1] "The TreeMix ML tree explains 99.55% of the variation. 0.995520233400649"
# [1] "M11"
# ...

# %%
mig <- c(1:12)
variance <- c( 0.971710055583651,0.97971898005183,0.984881723644755,0.988133578544556,0.989839236397274,
              0.991114968112155, 0.993280230355509, 0.994146485849138,0.995102987512876,0.995520233400649,0.996528963297873,0.996528963297873)
plot(mig, variance)
# Out:
# plot without title
